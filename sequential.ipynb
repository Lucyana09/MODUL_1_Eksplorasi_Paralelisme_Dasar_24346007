# %%
import random
import time
import math

def calculate_pi_serial(num_samples):
    inside_circle = 0
    for _ in range(num_samples):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        if x**2 + y**2 <= 1:
            inside_circle += 1
    return 4 * inside_circle / num_samples

if __name__ == "__main__":
    num_samples = 10_000_000
    
    print("PROGRAM SERIAL - MONTE CARLO π")
   
    start_time = time.time()
    pi_est = calculate_pi_serial(num_samples)
    end_time = time.time()
    
    execution_time = end_time - start_time
    
    print(f"Estimasi π: {pi_est}")
    print(f"Nilai π asli: {math.pi}")
    print(f"Error: {abs(pi_est - math.pi)}")
    print(f"Waktu eksekusi: {execution_time:.4f} detik")
# Out:
# PROGRAM SERIAL - MONTE CARLO π
# Estimasi π: 3.1412056
# Nilai π asli: 3.141592653589793
# Error: 0.0003870535897929628
# Waktu eksekusi: 5.2133 detik
